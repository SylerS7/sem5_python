# %%
import pandas as pd

data = {
    "SName": ["K. Aryan"],
    "SRoll": [2400520089],
    "SCourse": ["BCA"],
    "SAddress": ["KL University"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       SName       SRoll SCourse       SAddress
# 0  K. Aryan  2400520089     BCA  KL University
