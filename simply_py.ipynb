# %% [markdown]
# 1.	Store your name, age, and city in variables and print them.
# 2.	Swap two numbers using a temporary variable.
# 3.	Swap two numbers without using a temporary variable.
# 4.	Assign the same value to three variables.
# 5.	Assign different values to three variables in one statement.
# 6.	Print the type of integer, float, string, and boolean variables.
# 7.	Display the memory address of a variable using id().
# 8.	Create a global variable and access it inside a function.
# 9.	Create a local variable and observe its scope.
# 10.	Delete a variable and observe the resulting error.****

# %%
# Store your name, age, and city in variables and print them. 

name = "Aryan"
age = 20
city = "Guntur"
print(name,"\n",age,"\n",city)
# Out:
# Aryan
#  20
#  Guntur

# %%
# Swap two numbers using a temporary variable.

a = 5
b = 7

c = a 
a = b
b = c

print(a,b)
# Out:
# 7 5

# %%
# Swap two numbers using a temporary variable.
    
a = 3
b = 4

a = a+b
b = a-b
a = a - b

print(a,b)
# Out:
# 4 3

# %%
# Assign the same value to three variables.

a=b=c=69

print(a,b,c)
# Out:
# 69 69 69

# %%
# Assign different values to three variables in one statement.

a, b, c = 67, 68, 69
print(a, b, c)
# Out:
# 67 68 69

# %%
# Print the type of integer, float, string, and boolean variables.

a=5
b=5.1
c="string"
d=True

print(
    type(a),
    type(b),
    type(c),
    type(d)
)
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
# Display the memory address of a variable using id().

a = 90

print(
    id(a)
)
# Out:
# 11648200

# %%
# Create a global variable and access it inside a function.

g = 10

def add(l):
    return l + g

print(add(5))
# Out:
# 15

# %%
# Create a local variable and observe its scope.

def add(l):
    k = 50
    return l + k

print(add(5))
print(k)
# Out:
# 55
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_58/520786763.py in <cell line: 0>()
#       6
#       7 print(add(5))
# ----> 8 print(k)
#
# NameError: name 'k' is not defined

# %%
# Delete a variable and observe the resulting error.****
# o=0
print(o)
